# %%
import simultaneous_waveviewer
file = "/mnt/atlas01/projects/legend/data/com/raw/2022-04-13-sipm-test/run006/20220416-211154-m6-muon-amajl3-mmaj4-rtl2500.lh5"

simultaneous_waveviewer.simul_viewer(lh5_file_in = file,data_dir = "/raw",include_channel = ["OB-01","OB-02","OB-03","OB-06","OB-07","OB-08"],entry = [7530,7531],y_lim =[9850,50000], x_lim =[0,50000],stacked_view = False)
