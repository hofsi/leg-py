# %%
import apply_scaling as asc
from pygama.lgdo.lh5_store import ls
from pygama.lgdo.lh5_store import show
file = "/mnt/atlas01/users/shofinger/dsp_7/b/231824.lh5"
ls(file,"/ch000/dsp/energies")
# Out:
# ['ch000/dsp/energies']

# %%
asc.scaling(file, "calibration_data_231824","energies")
show(file)
# Out:
# /
# ├── ch000 · HDF5 group
# │   └── dsp · table{energies,trigger_pos}
# │       ├── energies · array_of_equalsized_arrays<2>{real}
# │       ├── energies_pe · array_of_equalsized_arrays<2>{real}
# │       └── trigger_pos · array_of_equalsized_arrays<2>{real}
# ├── ch001 · HDF5 group
# │   └── dsp · table{energies,trigger_pos}
# │       ├── energies · array_of_equalsized_arrays<2>{real}
# │       ├── energies_pe · array_of_equalsized_arrays<2>{real}
# │       └── trigger_pos · array_of_equalsized_arrays<2>{real}
# ├── ch002 · HDF5 group
# │   └── dsp · table{energies,trigger_pos}
# │       ├── energies · array_of_equalsized_arrays<2>{real}
# │       ├── energies_pe · array_of_equalsized_arrays<2>{real}
# │       └── trigger_pos · array_of_equalsized_arrays<2>{real}
# ├── ch003 · HDF5 group
# │   └── dsp · table{energies,trigger_pos}
# │       ├── energies · array_of_equalsized_arrays<2>{real}
# │       ├── energies_pe · array_of_equalsized_arrays<2>{real}
# ...
