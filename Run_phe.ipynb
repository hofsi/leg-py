# %%
import find_event as fe
from pygama.lgdo.lh5_store import show
from pygama.lgdo.lh5_store import ls
import simultaneous_waveviewer

#ls("/mnt/atlas01/users/shofinger/dsp_7/a/113433.lh5","ch000/")
file = "/mnt/atlas01/projects/legend/data/com/raw/2022-04-13-sipm-test/run006/20220414-063402-m6-muon-amajl3-mmaj4-rtl2500.lh5"
results, entrys = fe.find_event(file,fe.median,[1,0,1500])

# %%
#show("/mnt/atlas01/projects/legend/data/com/raw/2022-04-13-sipm-test/run006/20220414-063402-m6-muon-amajl3-mmaj4-rtl2500.lh5")

# %%
results, entrys = zip(*sorted(zip(results[0],entrys[0])))

# %%
simultaneous_waveviewer.simul_viewer(lh5_file_in = file,data_dir = "/raw",stacked_view=False,include_channel = ["OB-01"],entry = [2893, 740, 9419, 2759, 8253, 178, 11218, 727, 3397, 10882, 5000, 815, 3280, 7249, 10010])

# %%
print(results)
print(entrys)
# Out:
# (9942.093333333334, 9942.886, 9943.944, 9944.096, 9944.212666666666, 9944.572666666667, 9944.870666666666, 9944.912666666667, 9945.135333333334, 9945.176, 9945.348, 9945.568666666666, 9945.626, 9945.864666666666, 9946.061333333333, 9946.200666666668, 9946.22, 9946.242666666667, 9946.508666666667, 9946.516, 9946.614, 9946.74, 9946.794, 9946.989333333333, 9947.067333333332, 9947.259333333333, 9947.306, 9947.390666666666, 9947.460666666666, 9947.536666666667, 9947.672, 9947.681333333334, 9947.726, 9947.730666666666, 9947.783333333333, 9947.973333333333, 9948.085333333333, 9948.090666666667, 9948.108, 9948.198, 9948.344666666666, 9948.366666666667, 9948.384, 9948.399333333333, 9948.478, 9948.563333333334, 9948.568666666666, 9948.636666666667, 9948.680666666667, 9948.685333333333, 9948.718, 9948.748666666666, 9948.814, 9948.852666666668, 9948.868, 9948.908, 9948.968, 9948.984, 9948.984666666667, 9948.992666666667, 9949.012, 9949.039333333334, 9949.108, 9949.122666666666, 9949.144, 9949.15
# ...
