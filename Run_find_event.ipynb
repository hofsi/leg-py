# %%
import find_event as fe
from pygama.lgdo.lh5_store import show
from pygama.lgdo.lh5_store import ls
import simultaneous_waveviewer
file = "/mnt/atlas01/projects/legend/data/com/raw/2022-04-13-sipm-test/run006/20220416-211154-m6-muon-amajl3-mmaj4-rtl2500.lh5"
#show(file,"ch000/")

# %%
#fe.event_length(file,"ch001/raw/waveform/values")
fe.print_event_data(file,[7530, 7531, 7532, 7533, 7534, 7535, 7536, 7537, 7538, 7539,7540,7541,7370 ])
# Out:
#     eventnumber  baseline  channel            deadtime  \
# 0          7530      9980        2  0.0015551000062204
# 1          7531     10005        2  0.0015551000062204
# 2          7532     10022        2  0.0015551000062204
# 3          7533     10032        2  0.0015551000062204
# 4          7534     10034        2  0.0015551000062204
# 5          7535     10040        2  0.0015551000062204
# 6          7536     10039        2  0.0015551000062204
# 7          7537     10037        2  0.0015551000062204
# 8          7538     10038        2  0.0015551000062204
# 9          7539      9941        2  0.0015551000062204
# 10         7540      9949        2  0.0015551000062204
# 11         7541      9947        2  0.0015551000062204
# 12         7370      9947        2  0.0000000000000000
#
#                     runtime                 timestamp
# 0   2263.032457071999942855  1.650145777032457113e+09
# 1   2263.032505048000075476  1.650145777032505035e+09
# ...

# %%
results, entrys = fe.find_event(file,[fe.average],[[1,0,10000000,0,3000]],minfit=10100,include_channel = ["OB-01","OB-02","OB-03","OB-05","OB-06","OB-07","OB-08","OB-09","OB-12","OB-13","OB-14","OB-16","OB-17","OB-21","OB-22","OB-23","OB-24","OB-25","OB-26","OB-28","OB-29","OB-30","OB-31","OB-35","OB-36","OB-37","OB-38","OB-39","OB-40"], )
#["OB-01","OB-02","OB-03","OB-05","OB-06","OB-07","OB-08","OB-09","OB-12","OB-13","OB-14","OB-16","OB-17","OB-21","OB-22","OB-23","OB-24","OB-25","OB-26","OB-28","OB-29","OB-30","OB-31","OB-35","OB-36","OB-37","OB-38","OB-39","OB-40"]

# %%
#show("/mnt/atlas01/projects/legend/data/com/raw/2022-04-13-sipm-test/run006/20220414-063402-m6-muon-amajl3-mmaj4-rtl2500.lh5")

# %%
results0, entrys0 = zip(*sorted(zip(results[0],entrys[0])))
results1, entrys1 = zip(*sorted(zip(results[1],entrys[1])))
results2, entrys2 = zip(*sorted(zip(results[2],entrys[2])))

# %%
simultaneous_waveviewer.simul_viewer(lh5_file_in = file,data_dir = "/raw",include_channel = ["OB-01","OB-02","OB-03","OB-06","OB-07","OB-08"],entry = [7530],y_lim =[9850,50000], x_lim =[0,50000],stacked_view = True)
# Out:
# 6

# %%
simultaneous_waveviewer.simul_viewer(lh5_file_in = file,data_dir = "/raw",include_channel = ["OB-01","OB-02","OB-03","OB-05","OB-06","OB-07","OB-08","OB-09","OB-12","OB-13","OB-14","OB-16","OB-17","OB-21","OB-22","OB-23","OB-24","OB-25","OB-26","OB-28","OB-29","OB-30","OB-31","OB-35","OB-36","OB-37","OB-38","OB-39","OB-40"],entry = [7538],y_lim =[9850,50000], x_lim =[0,50000],stacked_view = True)
# Out:
# 29

# %%
simultaneous_waveviewer.simul_viewer(lh5_file_in = file,data_dir = "/raw",include_channel = ["OB-01","OB-02","OB-03","OB-05","OB-06","OB-07","OB-08","OB-09","OB-12","OB-13","OB-14","OB-16","OB-17","OB-21","OB-22","OB-23","OB-24","OB-25","OB-26","OB-28","OB-29","OB-30","OB-31","OB-35","OB-36","OB-37","OB-38","OB-39","OB-40"],entry = [7539],y_lim =[9850,50000], x_lim =[0,50000],stacked_view = True)
# Out:
# 29

# %%
print(results0)
print("")
print(entrys0)
print("")
print(results1)
print("")
print(entrys1)
print("")
print(results2)
print("")
print(entrys2)
# Out:
# (10101.596333333333, 10110.902, 10112.803666666667, 10115.074, 10116.140666666666, 10123.219666666666, 10124.605666666666, 10133.953666666666, 10143.636, 10144.552666666666, 10154.046666666667, 10155.307, 10157.943666666666, 10163.232, 10165.709, 10187.074666666667, 10193.281333333332, 10196.568666666666, 10210.621666666666, 10230.233666666667, 10235.051666666666, 10265.185666666666, 10281.784666666666, 10321.426333333333, 10328.626666666667, 10334.312333333333, 10340.319, 10375.282333333333, 10378.507, 10389.249333333333, 10394.667, 10397.899666666666, 10415.160333333333, 10418.286333333333, 10467.715666666667, 10523.21, 10552.025666666666, 10637.033666666666, 10672.899666666666, 10695.220333333333, 10794.591, 11896.165, 12333.945333333333, 23673.377666666667)
#
# ...

# %%
simultaneous_waveviewer.simul_viewer(lh5_file_in = file,data_dir = "/raw",entry = [ 10794],include_channel = ["OB-01","OB-02","OB-03","OB-05","OB-06","OB-07","OB-08","OB-09","OB-12","OB-13","OB-14","OB-16","OB-17","OB-21","OB-22","OB-23","OB-24","OB-25","OB-26","OB-28","OB-29","OB-30","OB-31","OB-35","OB-36","OB-37","OB-38","OB-39","OB-40"],y_lim =[9500,50000], x_lim =[0,50000],stacked_view = True)
# Out:
# 29
